# %% [markdown]
# # Data cleaning in Pandas

# %%
import pandas as pd

# %%
# Import excel file 
df = pd.read_excel("/Users/dibaspaudel/Desktop/Python/PandasYouTubeSeries/Customer Call List.xlsx")

# %%
# setting index to 'CustomerID'
df.set_index("CustomerID", inplace = True)

# %%
df
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger           NaN
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN           N/a
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee           NaN
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %%
# drop the duplicate

df = df.drop_duplicates()

# %%
# remove unusefull column

df.drop(columns = "Not_Useful_Column", inplace = True)
# Out:
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/2207731195.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = "Not_Useful_Column", inplace = True)

# %%
# cleaning data on "Last_Name"

# df['Last_Name'] = df["Last_Name"].str.lstrip('...') 
# df['Last_Name'] = df["Last_Name"].str.lstrip('/')
#df['Last_Name'] = df["Last_Name"].str.rstrip('_') 

df['Last_Name'] = df["Last_Name"].str.strip('123._/')
# Out:
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/3318559769.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Last_Name'] = df["Last_Name"].str.strip('123._/')

# %%
# formating Phone_Number (123-456-7890)

df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]', '')

# change into string before formatting

df['Phone_Number'] = df['Phone_Number'].apply(lambda x: str(x))

# formatting

df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])
# Out:
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/3428102741.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]', '')
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/3428102741.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]', '')
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/3428102741.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# remove na 

df['Phone_Number'] = df['Phone_Number'].str.replace('nan--', '')
df['Phone_Number'] = df['Phone_Number'].str.replace('Na--', '')
# Out:
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/372581579.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number'] = df['Phone_Number'].str.replace('nan--', '')
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/372581579.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number'] = df['Phone_Number'].str.replace('Na--', '')

# %%
# cleaning Address

df[['Street_Address', 'State', 'Zip_Code']] = df['Address'].str.split(',',2, expand = True)
# Out:
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/853052718.py:3: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['Street_Address', 'State', 'Zip_Code']] = df['Address'].str.split(',',2, expand = True)
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/853052718.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Street_Address', 'State', 'Zip_Code']] = df['Address'].str.split(',',2, expand = True)
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/853052718.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df['Paying Customer'] = df['Paying Customer'].str.replace('Yes','Y')
df['Paying Customer'] = df['Paying Customer'].str.replace('No','N')
df
# Out:
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/191892029.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer'] = df['Paying Customer'].str.replace('Yes','Y')
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/191892029.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer'] = df['Paying Customer'].str.replace('No','N')
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# ...

# %%
# category 


df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('Yes','Y')
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('No','N')

df
# Out:
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/4274508220.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('Yes','Y')
# /var/folders/1g/bm_7x7vd33xdzftxhw1sywp00000gn/T/ipykernel_25890/4274508220.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('No','N')
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# ...

# %%
# remove a NaN

#df = df.replace('N/a', '')
#df = df.replace('NaN', '')

# fill in NaN
df = df.fillna('')

# %%
df2 = df[df['Do_Not_Contact'].isin(['N', ''])]
df2
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1003           Walter       White
# 1005              Jon        Snow  876-678-3469
# 1007             Jeff      Winger
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee
# 1012            Harry      Potter
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent
# 1020           Anakin   Skywalker  876-678-3469
#
#                                    Address Paying Customer Do_Not_Contact  \
# CustomerID
# 1001                 123 Shire Lane, Shire               Y              N
# ...

# %%
df2 = df2[df2['Phone_Number'] != '']
df2
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1005              Jon        Snow  876-678-3469
# 1008         Sherlock      Holmes  876-678-3469
# 1010            Peter      Parker  123-545-5421
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1020           Anakin   Skywalker  876-678-3469
#
#                                    Address Paying Customer Do_Not_Contact  \
# CustomerID
# 1001                 123 Shire Lane, Shire               Y              N
# 1005                      123 Dragons Road               Y              N
# 1008                         98 Clue Drive               N              N
# 1010            25th Main Street, New York               Y              N
# ...

# %%
df2 = df2.reset_index()
df2
# Out:
#    index  CustomerID First_Name   Last_Name  Phone_Number  \
# 0      0        1001      Frodo     Baggins  123-545-5421
# 1      1        1005        Jon        Snow  876-678-3469
# 2      2        1008   Sherlock      Holmes  876-678-3469
# 3      3        1010      Peter      Parker  123-545-5421
# 4      4        1013        Don      Draper  123-543-2345
# 5      5        1014     Leslie       Knope  876-678-3469
# 6      6        1015       Toby  Flenderson  304-762-2467
# 7      7        1016        Ron     Weasley  123-545-5421
# 8      8        1017   Michael        Scott  123-643-9775
# 9      9        1020     Anakin   Skywalker  876-678-3469
#
#                           Address Paying Customer Do_Not_Contact  \
# 0           123 Shire Lane, Shire               Y              N
# 1                123 Dragons Road               Y              N
# 2                   98 Clue Drive               N              N
# ...
